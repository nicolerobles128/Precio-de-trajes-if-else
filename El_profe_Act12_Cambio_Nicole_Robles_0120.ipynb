# %% [markdown]
# <a href="https://colab.research.google.com/github/nicolerobles128/Precio-de-trajes-if-else/blob/main/El_profe_Act12_Cambio_Nicole_Robles_0120.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Nicole Robles NL = 46 Fecha 26/03/2026
# ### Calculando el cambio usando if else
# ### Mirar diagrama de flujo
# ## Las Variables:
# <img src="https://raw.githubusercontent.com/nicolerobles128/Calcular-cambio-if-else/refs/heads/main/Calcular%20cambio%20de%20una%20compra.JPG" alt="perrito negro" width="200" heigth="200">
# >
#
# 1. CP --> Costo del Producto
# 2. CD --> Cantidad de Dinero
# 3. Cambio
#
# ## Formulas:
# $Cambio = CD - CP$
#
# ## Diagrama de flujo LucidChat:
# <img src="https://raw.githubusercontent.com/nicolerobles128/Calcular-cambio-if-else/refs/heads/main/DF%20if%20else%20Cambio2.png" alt="perrito negro" width="350" heigth="500">

# %%
# Calculando el cambio usando if else
# Datos de entrada CD, CP
# Mostrar Cambio si es falso
# Si es verdadero mostras No alcanza
CP = int(input("Ingrese el costo del producto: "))
CD = int(input("Ingrese la cantidad de dinero: "))
if CP > CD:
  print("No alcanza")
else:
  Cambio = CD - CP
  print("El cambio es:",Cambio)
print("Fin del programa")
print("Programa realizado por Nicole Robles NL = 46")
# Out:
# Ingrese el costo del producto: 500
# Ingrese la cantidad de dinero: 400
# No alcanza
# Fin del programa
# Programa realizado por Nicole Robles NL = 46

# %% [markdown]
# ## Relacion entre codigo y Diagrama de Flujo
#
# <img src="https://raw.githubusercontent.com/nicolerobles128/Calcular-cambio-if-else/refs/heads/main/TLDraw%20codigo%20DF.png" alt="perrito negro" width="800" heigth="500">
